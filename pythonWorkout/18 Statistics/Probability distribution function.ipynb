# %% [markdown]
# __Probability distribution function__
# - what do you mean pdf ?
#     - Types of probability distribution function
#         - Probability mass function (pmf)
#             - Used for discrete random variable
#         - Probability density function (pdf)
#             - used for continuous random variable

# %% [markdown]
# __Probability mass function (used for discrete random variable)__
#   - When we say discrete random variable : the variables are in whole numbers rather than a range of values.
#     - The probability mass function represents the graphical distribution of the probabilities.
#
# - __cumulative density function__
#     - When we represent the values of the sample in the x-axis and probability should be from 0 to 1 in y-axis.
#     - he CDF helps calculate probabilities for ranges of values by simple subtraction. For instance, P(a≤X≤b)=F(b)−F(a), where F(x) is the CDF.
#     - Cumulative density function enables the user to understand the consolidation of probabilities when they are asked in range.
#     - In a discrete example, where a unbiased dice is rolled, the outcomes are (1,2,3,4,5,6). If the question is what is Pr(x=6) then it is 1/6. What if we ask what is probability where Pr(2<x<>4) = cdf(2)- cdf(4) = 2/6 - 4/6 =2/6 = 1/3
#     - this graph : ![image.png](attachment:image.png)
#     - is converted into CDF : ![image-2.png](attachment:image-2.png)
#     - Slope or portion of the graph is called Probability density function.

# %% [markdown]
# - __Probability Density function__
#    - Helps to represent the continuous random variable like weight or height or other decimal values or any range.
#    - Pdf : it is just the gradient of cumulative density function.
#    - Gradient --> slope --> dy/dx --> change in y direction / change in x direction --> (y2-y1)/(x2-x1) --> visual in graph
#    - ![image.png](attachment:image.png)
# - __properties of PDF__
#    - The pdf is always positive , f(x)>= 0 for all values of x
#    - The total area under the curve = 1
# - __Area under the curve__
#    - The selected area under the curve gives the probability density function.
#    - let's assume the pdf = 33%, which means there 33% likelihood of this event to occur.

# %% [markdown]
# __Types of Probability distribution function__
# - When a dataset is provided to you, there may be different features within it.
#  - Each feature across the rows might follow different distributions.
#    - for eg. I am having a dataset having features like age, height and weight
#       - Here my age would follow a distinct distribution unlike height and weight. Similarly for other cases as well.
# - __Types__
#   1. Bernoulli distribution --> Binary outcomes --> discrete random variable
#   2. Binomial distribution --> Discrete number of outcomes -->discrete random variable
#   3. Normal distribution or Gaussian distribution --> uses pdf and has assumptions within it --> continuous random variable
#   4. Poisson distribution --> uses PMF -->  discrete random variable
#   5. Log Normal distribution --> uses pdf --> continuous random variable
#   6. uniform distribution --> uses PMF --> discrete random variable

# %% [markdown]
# # Bernoulli's Distribution
#    - The possible number of outcomes are two.
#           - Success probability : p
#           - failure probability : 1-p
#        - Discrete random variable since 2 outcomes --> then we will use probability mass function (pmf)
#        - The formula used in place of PMF = P^k * (1-P)^k
#          - if k =1 , the PMF = P
#          - if k = 0, the PMF = 1-P
#    - Mean of this distribution function : E(x) = Pr(p)*P + Pr(q)*Q
#       - where Q = 1 - P
#
#    - Median of this distribution function
#       - when Q>P then median = 0
#       - when Q=P then median = 0.5
#       - when Q<P then median = 1
#    - Mode : if p > q then mode = p else mode = q
#    - Variance  : sigma^2 = pq
#    - Standard deviation : sigma = sqrt(pq)

# %% [markdown]
# - ![image.png](attachment:image.png)
# - ![image-2.png](attachment:image-2.png)
# - ![image-3.png](attachment:image-3.png)
# - ![image-4.png](attachment:image-4.png)
# - ![image-5.png](attachment:image-5.png)

# %%
import pandas as pd

# we are defining the successful outcome => 1 and failed outcome => 0
# p = 1 and (1-p) or q = 0
outcomes = [0,1]

## I am taking an biased coin, where in on a long run gives heads for 70% of the time : p = 0.7 then q = 0.3
# then mean = p 
p = 0.7
q = 0.3 

# since p is more than 0.5 then mean = p
mean = p 

# if p > 0.5 median =1 , if p <= 0.5 then median = 0
# Since p = 0.7
median = 1
mode = 1
# variance 
variance = p*q

# standard deviation 
sd = (variance)**(0.5)


print(f"mean : {mean}")
print(f"median : {median}")
print(f"mode : {mode}")
print(f"variance : {variance}")
print(f"S.D : {sd}")
# Out:
# mean : 0.7
# median : 1
# mode : 1
# variance : 0.21
# S.D : 0.458257569495584
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Binomial Distribution
# - Collection of bernaulli's event is called binomial distribution.
# - if a coin is flip once it is called bernaulli's event, if they are flipped more than once and the outcomes are noted this becomes the Binomial distribution
# - In other words : If n number of times a coins is flipped it becomes binomial distribution, if n = 1 it is bernaulli's event.
# - **Conditions**
#   - Discrete random variable
#   - The outcomes should be binary : yes/No, 0/1.
#   - This experimentation should be done for n trials
# - Inputs : p and n --> p : probability of success after n trials , n : number of trials
#   - for eg. p = 0.7 after n = 20 trials, p = 0.6 after after n = 200 trials
#
# - Notation:(B(n,p))
#
# - Probability mass function :
#   - ![image.png](attachment:image.png)
#   -  ![image-2.png](attachment:image-2.png)
#   - mean = n*p
#   - variance = n*p*q
#   - standard deviation = sqrt(n*p*q)
#   - ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Poisson Distribution
#
# - This is a discrete probability distribution function.
# - If number of events are happening within specified time framework or fixed interval of time then we call this distribution as Poisson distribution.
# - In the above 2 distribution there is no reference of time period, but this distribution does.
#
# - Eg. 1 : No. of people visiting the railway station booth or hospital etc.
# - Eg. 2 : No. of person visiting banks every hour.
# - ![image.png](attachment:image.png)
# - ![image-2.png](attachment:image-2.png)
# - Point to note
#    - *When the lambda is increasing the bell shaped curve is also emerging*
#    - *Probability mass function : ![image-3.png](attachment:image-3.png)*
#    - *Mean: lambda x t , where lambda is the expected number of events occur at every interval of hour, t:time interval*

# %% [markdown]
# # Normal/Gaussian distribution

# %% [markdown]
# - Gaussian distribution function or Normal distribution function
# - This is applicable for __continuous distribution function__
# - Follows Bell curve
# - here, mean = median = mode
# - Follows symmetric distribution
# - Notation : N(mean, SD)
# - Input parameters
#   - mean : has real value
#   - SD : real values and is always above 0
#   - x : which a continuous random variable but a real number
# - Since it is continuos random variable --> we will follow probability density function

# %% [markdown]
# - ![image-3.png](attachment:image-3.png)
# - *We can observe that, when variance is increasing the curves is smoothening out and the bell shape is nullified and the spread is increasing*
# - Eg. Weights,heights,age with months of students
# - ![image-5.png](attachment:image-5.png)
# -
# - ![image.png](attachment:image.png)

# %% [markdown]
# - Emperical rule of normal or gaussian distribution
#   - ![image.png](attachment:image.png) --> Geeks for geeks
#   - *The above diagram explains that if i pick a value from the continuos random variable, there is 68% chances that they will fall under mean-+sigma*
#
#   - Let me consider a dataframe, where we have recorded the information of students. This dataframe has multiple features and values. If i pick a feature called height, then it is continuos random variable as it might have fractional or decimal values. Within the height list, if i pick a value of height then there is 68% chance that the value will be lying between mu +- sigma, 95% chance that it will be lying between mu +- 2sigma, 99.7% chance that it will be lying between  mu +- 3sigma

# %% [markdown]
# # Standard Normal distribution
